# %%
import scanpy as sc

# %%
adata=sc.read("/dfs3b/ruic20_lab/junw42/HCA_ON/data/5_refine_major/scvi/Oligodendrocyte/clean/oligo_opc_seurat_new_scvi.h5ad")

# %%
mk={"OPC":["PDGFRA","BCAN","SOX6"], "immune oligo": ["APOE", "CD74"], "Oligo1":["CDH20","RBFOX1"], "Oligo2":["LURAP1L-AS1","CDH19"], "Oligo5": ["KLK6","GJB1"], "Oligo6": ["OPALIN","LINC00844"]}

# %%
sc.pl.dotplot(adata, mk, groupby="subclass")

# %%
sc.pl.dotplot(adata, "BTG3", groupby="subclass")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 292428 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'pANN', 'DF.classifications', 'reactionid', 'sampleid', 'donor', 'race', 'gender', 'age', 'tissue', 'suspension', 'technology', 'sampleid_legacy', '_scvi_batch', '_scvi_labels', 'majorclass', 'majorclass1', 'source', 'age_year', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'subclass', 'leiden'
#     uns: 'umap'
#     obsm: 'X_scVI', 'X_umap'
#     layers: 'counts'

# %%
import scanpy as sc
adata=sc.read("/dfs3b/ruic20_lab/junw42/HCA_ON/data/5_refine_major/scvi/Oligodendrocyte/clean/veloc/oligo_opc_seurat_new_scvi_hvg_2000_raw_velocity.h5ad")
adata1=adata[adata.obs["majorclass1"]=="Oligodendrocyte"]
# Out:
# /opt/apps/python/3.10.2/lib/python3.10/site-packages/anndata/compat/__init__.py:371: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /opt/apps/python/3.10.2/lib/python3.10/site-packages/anndata/compat/__init__.py:371: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
adata1

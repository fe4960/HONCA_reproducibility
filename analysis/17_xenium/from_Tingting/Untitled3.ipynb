# %%
import scanpy as sc

# %%
dir="/dfs3b/ruic20_lab/junw42"
adata=sc.read(f"{dir}/HCA_ON/data/5_refine_major/scvi/Oligodendrocyte_precursor_cell/clean/Oligodendrocyte_precursor_cell_subclass_seurat.h5ad")

# %%
mk=["EGFR","NES","ZFP36L1","GFAP","BCAN","PTPRZ1","NES","RFX4","TTYH1","CCND1","MDFI"]
mk1=["VIM", "FABP7", "TTYH1", "SPARCL1", "HES1", "RMST", "CLU", "FOS"]
mk2=["S100B", "KCND2", "OLIG1", "PCDH15", "SCRG1", "LHFPL3", "OPCML", "APOD",  "OLIG2"]
mk3=["OLIG1", "OLIG2", "SOX6", "NKX2-2",  "SOX10"]
mk4=["LUZP2", "NCALD", "NR0B1", "ETV1", "MITF", "TRAF4"]
mk5=["HES1", "GLIS3", "FOS", "NFIA", "NFIB", "HES4", "TSC22D4", "NFATC2", "JUNB", "HES5",  "FOXJ1"]

# %%
sc.pl.dotplot(adata,mk5,groupby="subclass")

# %%
mk4=["LUZP2", "NCALD", "NR0B1", "ETV1", "MITF", "TRAF4"]
